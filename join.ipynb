# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"MERSNew(raw).xlsx")
dp = pd.read_excel(r"SARS2New(raw).xlsx")

# %%
mers = pd.DataFrame(df)
sars2oc43 = pd.DataFrame(dp)

# %%
join = pd.merge(sars2oc43, mers, on = "Gene_ID")

# %%
join
# Out:
#                Gene_ID  sgCTRL-Mock-Rep1  sgCTRL-Mock-Rep2  sgCTRL-Mock-Rep3  \
# 0      ENSG00000000003              1918              1892              2025
# 1      ENSG00000000005                 0                 0                 0
# 2      ENSG00000000419               860              1110              1006
# 3      ENSG00000000457               337               330               361
# 4      ENSG00000000460               323               389               281
# ...                ...               ...               ...               ...
# 52177  ENSG00000273486                18                10                17
# 52178  ENSG00000273487                 0                 0                 0
# 52179  ENSG00000273489                 0                 0                 0
# 52180  ENSG00000273492                 7                 7                 3
# 52181  ENSG00000273493                 0                 0                 0
#
# ...

# %%
join.to_excel("Master_Data(New).xlsx")
